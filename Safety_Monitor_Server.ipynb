# %%
import cv2
import numpy as np
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
from mediapipe.framework.formats import landmark_pb2
from cv2 import destroyAllWindows
import math
import time
import socket
import struct
import pickle
import threading

model_path = "C:\\Users\\240329Z10\\project\\pose_landmarker_full.task"

video_source = 'C:\\Users\\240329Z10\\project\\video4.mp4'
#video_source = 0

f=open("C:\\Users\\240329Z10\\project\\coordinate.txt", 'w')

num_poses = 4
min_pose_detection_confidence = 0.5
min_pose_presence_confidence = 0.5
min_tracking_confidence = 0.5

high_risk_times = {}
very_high_risk_times = {}

# 檢查是否超過高風險閾值，如果是，開始計時
def check_high_risk_score(person_id, score):
    global high_risk_times
    if score >= 8:
         # 如果該人員尚未在高風險時間中，則開始計時
        if person_id not in high_risk_times:
            high_risk_times[person_id] = time.time()
            print(f"Person {person_id}: High risk detected. Timer started.")
       
    

# 檢查是否超過非常高風險閾值，如果是，開始計時
def check_very_high_risk_score(person_id, score):
    global very_high_risk_times
    if score >= 11:
        # 如果該人員尚未在非常高風險時間中，則開始計時
        if person_id not in very_high_risk_times:
            very_high_risk_times[person_id] = time.time()
            print(f"Person {person_id}: Very high risk detected. Timer started.")

# 檢查是否低於高風險閾值，如果是，停止計時
def check_low_risk_score(person_id, score):
    global high_risk_times
    if person_id in high_risk_times and score < 8:
        # 如果該人員正在高風險時間中，則停止計時並計算經過的時間
        elapsed_time = time.time() - high_risk_times.pop(person_id)
        print(f"Person {person_id}: High risk resolved. Elapsed time: {elapsed_time} seconds.")

# 檢查是否低於非常高風險閾值，如果是，停止計時
def check_low_very_high_risk_score(person_id, score):
    global very_high_risk_times
    if person_id in very_high_risk_times and score < 11:
        # 如果該人員正在非常高風險時間中，則停止計時並計算經過的時間
        elapsed_time = time.time() - very_high_risk_times.pop(person_id)
        print(f"Person {person_id}: Very high risk resolved. Elapsed time: {elapsed_time} seconds.")

def stop_all_timers():
    global high_risk_times
    global very_high_risk_times
    print("Stopping all timers...")
    # 檢查高風險計時器並停止計時
    for person_id, start_time in high_risk_times.items():
        elapsed_time = time.time() - start_time
        print(f"Person {person_id}: High risk resolved. Elapsed time: {elapsed_time} seconds.")
    #high_risk_times = {}
    
    # 檢查非常高風險計時器並停止計時
    for person_id, start_time in very_high_risk_times.items():
        elapsed_time = time.time() - start_time
        print(f"End Person {person_id}: Very high risk resolved. Elapsed time: {elapsed_time} seconds.")
    #very_high_risk_times = {}

def draw_sector_indicator(annotated_image, score, x, y, idx):
    # Define sector colors and angles
    sector_colors = [
        ((0, 255, 0) , 1 , 1),       # Green
        ((255, 255, 0), 2 , 2),     # Yellow
        ((255, 165, 0) , 4 , 4),     # Orange
        ((255, 0, 0), 7 , 3),      # Red
        ((139, 0, 0), 11 , 2)      # Dark Red
    ]
    
    radius = 50
    center = (x + radius, y + radius)
    arrow_length = radius

    cv2.ellipse(annotated_image, center, (radius, radius), 0, 180, 195, (0, 255, 0), -1)
    cv2.ellipse(annotated_image, center, (radius, radius), 0, 195, 225, (255, 255, 0), -1)
    cv2.ellipse(annotated_image, center, (radius, radius), 0, 225, 285, (255, 165, 0), -1)
    cv2.ellipse(annotated_image, center, (radius, radius), 0, 285, 330, (255, 0, 0), -1)
    cv2.ellipse(annotated_image, center, (radius, radius), 0, 330, 360, (139, 0, 0), -1)
   
    
    # Calculate arrow angle
    arrow_angle = 180 - (score - 1) * 9
    arrow_end = (
        int(center[0] + arrow_length * np.cos(np.radians(arrow_angle))),
        int(center[1] - arrow_length * np.sin(np.radians(arrow_angle)))
    )
    # Draw arrow
    cv2.arrowedLine(annotated_image, center, arrow_end, (255,255,255), 2, tipLength=0.1)
    cv2.rectangle(annotated_image, (x-10, y+radius+6), (x+100, y+radius+30), (0, 0, 0), -1, cv2.LINE_AA)
    #cv2.putText(annotated_image, f'person {idx+1}', (x, y+radius+20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
    cv2.putText(annotated_image, f'Score: {score}', (x, y+radius+20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


def draw_landmarks_on_image(rgb_image, detection_result):
    pose_landmarks_list = detection_result.pose_landmarks
    annotated_image = np.copy(rgb_image)

    # Loop through the detected poses to visualize.
    for idx in range(len(pose_landmarks_list)):
        pose_landmarks = pose_landmarks_list[idx]

        min_x, min_y, max_x, max_y = float('inf'), float('inf'), -float('inf'), -float('inf')
        # Calculate bounding box coordinates for the current person
        for landmark in pose_landmarks:
            min_x = min(min_x, landmark.x)
            min_y = min(min_y, landmark.y)
            max_x = max(max_x, landmark.x)
            max_y = max(max_y, landmark.y)

        width = max_x - min_x
        height = max_y - min_y
        min_x -= width * 0.1
        min_y -= height * 0.1
        max_x += width * 0.1
        max_y += height * 0.1
        
        pose_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        pose_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(
                x=landmark.x,
                y=landmark.y,
                z=landmark.z) for landmark in pose_landmarks
        ])
        mp.solutions.drawing_utils.draw_landmarks(
            annotated_image,
            pose_landmarks_proto,
            mp.solutions.pose.POSE_CONNECTIONS,
            mp.solutions.drawing_styles.get_default_pose_landmarks_style()
        )
        
        landmarks_array = []
    
        for landmark_index, landmark in enumerate(pose_landmarks):
            landmarks_array.append([landmark_index, landmark.x, landmark.y, landmark.z])
        score = calculate_score(landmarks_array)
        # Draw bounding box for the current person
        cv2.rectangle(
            annotated_image,
            (int(min_x * annotated_image.shape[1]), int(min_y * annotated_image.shape[0])),
            (int(max_x * annotated_image.shape[1]), int(max_y * annotated_image.shape[0])),
            (255, 0, 0), 2
        )

        # Draw score indicator next to the bounding box
        indicator_x = int(max_x * annotated_image.shape[1]) + 10  # 10 pixels to the right of the bounding box
        indicator_y = int(min_y * annotated_image.shape[0])
        draw_sector_indicator(annotated_image, score, indicator_x, indicator_y, idx)
        
        check_high_risk_score(idx+1, score)
        check_very_high_risk_score(idx+1, score)
        check_low_risk_score(idx+1, score)
        check_low_very_high_risk_score(idx+1, score)
    return annotated_image

        


def calculate_angle2D(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle


def calculate_score(landmarks):
    score=1
    # Get coordinates
    nose = [landmarks[0][1], landmarks[0][2], landmarks[0][3]]
    left_ear = [landmarks[7][1], landmarks[7][2], landmarks[7][3]]
    right_ear = [landmarks[8][1], landmarks[8][2], landmarks[8][3]]
    left_shoulder = [landmarks[11][1], landmarks[11][2], landmarks[11][3]]
    right_shoulder = [landmarks[12][1], landmarks[12][2], landmarks[12][3]]
    left_elbow = [landmarks[13][1], landmarks[13][2], landmarks[13][3]]
    right_elbow = [landmarks[14][1], landmarks[14][2], landmarks[14][3]]
    left_wrist = [landmarks[15][1], landmarks[15][2], landmarks[15][3]]
    right_wrist = [landmarks[16][1], landmarks[16][2], landmarks[16][3]]
    left_index = [landmarks[19][1], landmarks[19][2], landmarks[19][3]]
    right_index = [landmarks[20][1], landmarks[20][2], landmarks[20][3]]
    left_hip = [landmarks[23][1], landmarks[23][2], landmarks[23][3]]
    right_hip = [landmarks[24][1], landmarks[24][2], landmarks[24][3]]
    left_knee = [landmarks[25][1], landmarks[25][2], landmarks[25][3]]
    right_knee = [landmarks[26][1], landmarks[26][2], landmarks[26][3]]
    left_ankle = [landmarks[27][1], landmarks[27][2], landmarks[27][3]]
    right_ankle = [landmarks[28][1], landmarks[28][2], landmarks[28][3]]
        
    neck = [(left_shoulder[0]+right_shoulder[0])/2, (left_shoulder[1]+right_shoulder[1])/2, (left_shoulder[2]+right_shoulder[2])/2]
    hip = [(left_hip[0]+right_hip[0])/2, (left_hip[1]+right_hip[1])/2, (left_hip[2]+right_hip[2])/2]
    trunk = [(neck[0]+hip[0])/2, (neck[1]+hip[1])/2, (neck[2]+hip[2])/2]
    ear = [(left_ear[0]+right_ear[0])/2, (left_ear[1]+right_ear[1])/2, (left_ear[2]+right_ear[2])/2]

     # Calculate other landmark
    extend = np.sqrt((trunk[0] - neck[0])**2 + (trunk[1] - neck[1])**2 + (trunk[2] - neck[2])**2)
    
    
    neck_vec2 = np.array([(trunk[0] - neck[0]), (trunk[1] - neck[1]), (trunk[2]-neck[2])])
    scaled_neck_vec2 = (extend / np.linalg.norm(neck_vec2)) * neck_vec2
    trunk_neck_vec = [(neck[0]-scaled_neck_vec2[0]), (neck[1]-scaled_neck_vec2[1]), (neck[2]-scaled_neck_vec2[2])]
    
    trunk_vertical = [trunk[0],trunk[1]-extend,trunk[2]]
    
    left_wrist_vec = np.array([(left_elbow[0] - left_wrist[0]), (left_elbow[1] - left_wrist[1]), (left_elbow[2]-left_wrist[2])])
    scaled_left_wrist_vec = (extend / np.linalg.norm(left_wrist_vec)) * left_wrist_vec
    left_elbow_wrist_vec = [(left_wrist[0]-scaled_left_wrist_vec[0]), (left_wrist[1]-scaled_left_wrist_vec[1]), (left_wrist[2]-scaled_left_wrist_vec[2])]

    right_wrist_vec = np.array([(right_elbow[0] - right_wrist[0]), (right_elbow[1] - right_wrist[1]), (right_elbow[2]-right_wrist[2])])
    scaled_right_wrist_vec = (extend / np.linalg.norm(right_wrist_vec)) * right_wrist_vec
    right_elbow_wrist_vec = [(right_wrist[0]-scaled_right_wrist_vec[0]), (right_wrist[1]-scaled_right_wrist_vec[1]), (right_wrist[2]-scaled_right_wrist_vec[2])]  

     #calculate angle
    angle_neck = calculate_angle2D([trunk_neck_vec[0],trunk_neck_vec[1]], [neck[0],neck[1]], [nose[0],nose[1]])
    angle_neck = round(angle_neck,2)

    angle_trunk = calculate_angle2D([trunk_vertical[0],trunk_vertical[1]], [trunk[0],trunk[1]], [neck[0],neck[1]])
    angle_trunk = round(angle_trunk,2)
    
    angle_left_leg = calculate_angle2D([left_ankle[0],left_ankle[1]], [left_knee[0],left_knee[1]], [left_hip[0],left_hip[1]])
    angle_left_leg = 180-angle_left_leg
    angle_left_leg = round(angle_left_leg,2)
    

    angle_right_leg = calculate_angle2D([right_ankle[0],right_ankle[1]], [right_knee[0],right_knee[1]], [right_hip[0],right_hip[1]])
    angle_right_leg = 180-angle_right_leg
    angle_right_leg = round(angle_right_leg,2)
    

    angle_left_upper_arm = calculate_angle2D([trunk[0],trunk[1]], [left_shoulder[0],left_shoulder[1]], [left_elbow[0],left_elbow[1]])
    angle_left_upper_arm = round(angle_left_upper_arm,2)

    angle_right_upper_arm = calculate_angle2D([trunk[0],trunk[1]], [right_shoulder[0],right_shoulder[1]], [right_elbow[0],right_elbow[1]])
    angle_right_upper_arm = round(angle_right_upper_arm,2)
    

    angle_left_lower_arm = calculate_angle2D([left_shoulder[0], left_shoulder[1]], [left_elbow[0], left_elbow[1]], [left_wrist[0], left_wrist[1]])
    angle_left_lower_arm = 180-angle_left_lower_arm
    angle_left_lower_arm = round(angle_left_lower_arm, 2)


    angle_right_lower_arm = calculate_angle2D([right_shoulder[0], right_shoulder[1]], [right_elbow[0], right_elbow[1]], [right_wrist[0], right_wrist[1]])
    angle_right_lower_arm = 180-angle_right_lower_arm
    angle_right_lower_arm = round(angle_right_lower_arm, 2)
    

    angle_left_wrist = calculate_angle2D([left_elbow_wrist_vec[0], left_elbow_wrist_vec[1]], [left_wrist[0], left_wrist[1]], [left_index[0], left_index[1]])
    angle_left_wrist = round(angle_left_wrist, 2)
    

    angle_right_wrist = calculate_angle2D([right_elbow_wrist_vec[0], right_elbow_wrist_vec[1]], [right_wrist[0], right_wrist[1]], [right_index[0], right_index[1]])
    angle_right_wrist = round(angle_right_wrist, 2)

    scoreA=0
    scoreB=0
    scoreleg=0
    scoreupper_arm=0
    scorelower_arm=0
    scorewrist=0

    if(angle_neck>=0 and angle_neck<=20):
        score_neck=1
    else:
        score_neck=2

    if(angle_trunk==0):
        score_trunk=1
    elif(angle_trunk>=-20 and angle_trunk<=20):
        score_trunk=2
    elif(angle_trunk<-20 or (angle_trunk>20 and angle_trunk<=60)):
        score_trunk=3
    else:
        score_trunk=4

    if(angle_left_leg>=30 and angle_left_leg<=60):
        score_left_leg=2
    elif(angle_left_leg>60):
        score_left_leg=3
    else:
        score_left_leg=1
    
    if(angle_right_leg>=30 and angle_right_leg<=60):
        score_right_leg=1
    elif(angle_right_leg>60):
        score_right_leg=2
    else:
        score_right_leg=0

    score_leg=math.floor((score_left_leg+score_right_leg)/2)

    if(angle_left_upper_arm>=-20 and angle_left_upper_arm<=20):
        score_left_upper_arm=1
    elif(angle_left_upper_arm<-20 or (angle_left_upper_arm>20 and angle_left_upper_arm<=45)):
        score_left_upper_arm=2
    elif(angle_left_upper_arm>45 and angle_left_upper_arm<=90):
        score_left_upper_arm=3
    else:
        score_left_upper_arm=4

    if(angle_right_upper_arm>=-20 and angle_right_upper_arm<=20):
        score_right_upper_arm=1
    elif(angle_right_upper_arm<-20 or (angle_right_upper_arm>20 and angle_right_upper_arm<=45)):
        score_right_upper_arm=2
    elif(angle_right_upper_arm>45 and angle_right_upper_arm<=90):
        score_right_upper_arm=3
    else:
        score_right_upper_arm=4

    score_upper_arm=math.floor((score_left_upper_arm+score_right_upper_arm)/2)

    if(angle_left_lower_arm>=60 and angle_left_lower_arm<=100):
        score_left_lower_arm=1
    elif(angle_left_lower_arm>100 or (angle_left_lower_arm>=0 and angle_left_lower_arm<60)):
        score_left_lower_arm=2

    if(angle_right_lower_arm>=60 and angle_right_lower_arm<=100):
        score_right_lower_arm=1
    elif(angle_right_lower_arm>100 or (angle_right_lower_arm>=0 and angle_right_lower_arm<60)):
        score_right_lower_arm=2

    score_lower_arm=math.floor((score_left_lower_arm+score_right_lower_arm)/2)

    if(angle_left_wrist>=-15 and angle_left_wrist<=15):
        score_left_wrist=1
    else:
        score_left_wrist=2

    if(angle_right_wrist>=-15 and angle_right_wrist<=15):
        score_right_wrist=1
    else:
        score_right_wrist=2

    score_wrist=math.floor((score_left_wrist+score_right_wrist)/2)

    # Calculate scoreA
    if score_neck == 1:
        if score_trunk == 1:
            scoreA = score_leg
        elif score_trunk == 2:
            scoreA = score_leg + 1
        elif score_trunk == 3:
            if score_leg == 1:
                scoreA = 2
            else:
                scoreA = score_leg + 2
        elif score_trunk == 4:
            if score_leg == 1:
                scoreA = 3
            else:
                scoreA = score_leg + 3
        else:
            if score_leg == 1:
                scoreA = 4
            else:
                scoreA = score_leg + 4
    elif score_neck == 2:
        if score_trunk == 1:
            scoreA = score_leg
        elif score_trunk == 2:
            scoreA = score_leg + 2
        elif score_trunk == 3:
            scoreA = score_leg + 3
        elif score_trunk == 4:
            scoreA = score_leg + 4
        else:
            scoreA = score_leg + 5
    else:
        if score_trunk == 1:
            if score_leg == 1 or score_leg == 2:
                scoreA = 3
            else:
                scoreA = score_leg + 2
        elif score_trunk == 2:
            scoreA = score_leg + 3
        elif score_trunk == 3:
            scoreA = score_leg + 4
        elif score_trunk == 4:
            scoreA = score_leg + 5
        else:
            if score_leg == 4:
                scoreA = 9
            else:
                scoreA = score_leg + 6

    # Calculate scoreB
    if score_lower_arm == 1:
        if score_upper_arm == 1:
            if score_wrist == 1:
                scoreB = 1
            else:
                scoreB = 2
        elif score_upper_arm == 2:
            scoreB = score_wrist
        elif score_upper_arm == 3:
            scoreB = score_wrist + 2
        elif score_upper_arm == 4:
            if score_wrist == 1:
                scoreB = 4
            else:
                scoreB = 5
        elif score_upper_arm == 5:
            scoreB = score_wrist + 5
        else:
            if score_wrist == 1:
                scoreB = 7
            else:
                scoreB = 8
    else:
        if score_upper_arm == 1:
            scoreB = score_wrist
        elif score_upper_arm == 2:
            scoreB = score_wrist + 1
        elif score_upper_arm == 3:
            if score_wrist == 1:
                scoreB = 4
            else:
                scoreB = 5
        elif score_upper_arm == 4:
            scoreB = score_wrist + 4
        elif score_upper_arm == 5:
            if score_wrist == 1:
                scoreB = 7
            else:
                scoreB = 8
        else:
            if score_wrist == 1:
                scoreB = 8
            else:
                scoreB = 9

    # Calculate final score
    if scoreA == 1:
        if scoreB < 4:
            score = 1
        elif scoreB < 5:
            score = 2
        elif scoreB < 7:
            score = 3
        elif scoreB < 8:
            score = 4
        elif scoreB < 9:
            score = 5
        elif scoreB < 10:
            score = 6
        else:
            score = 7
    elif scoreA == 2:
        if scoreB < 2:
            score = 1
        elif scoreB < 4:
            score = 2
        elif scoreB < 5:
            score = 3
        elif scoreB < 7:
            score = 4
        elif scoreB < 8:
            score = 5
        elif scoreB < 10:
            score = 6
        elif scoreB < 12:
            score = 7
        else:
            score = 8
    elif scoreA == 3:
        if scoreB < 2:
            score = 2
        elif scoreB < 5:
            score = 3
        elif scoreB < 6:
            score = 4
        elif scoreB < 7:
            score = 5
        elif scoreB < 8:
            score = 6
        elif scoreB < 10:
            score = 7
        else:
            score = 8
    elif scoreA == 4:
        if scoreB < 2:
            score = 3
        elif scoreB < 5:
            score = 4
        elif scoreB < 6:
            score = 5
        elif scoreB < 7:
            score = 6
        elif scoreB < 8:
            score = 7
        elif scoreB < 10:
            score = 8
        else:
            score = 9
    elif scoreA == 5:
        if scoreB < 4:
            score = 4
        elif scoreB < 5:
            score = 5
        elif scoreB < 6:
            score = 6
        elif scoreB < 7:
            score = 7
        elif scoreB < 9:
            score = 8
        else:
            score = 9
    elif scoreA == 6:
        if scoreB < 4:
            score = 6
        elif scoreB < 5:
            score = 7
        elif scoreB < 7:
            score = 8
        elif scoreB < 9:
            score = 9
        else:
            score = 10
    elif scoreA == 7:
        if scoreB < 4:
            score = 7
        elif scoreB < 5:
            score = 8
        elif scoreB < 8:
            score = 9
        elif scoreB < 10:
            score = 10
        else:
            score = 11
    elif scoreA == 8:
        if scoreB < 4:
            score = 8
        elif scoreB < 5:
            score = 9
        elif scoreB < 10:
            score = 10
        else:
            score = 11
    elif scoreA == 9:
        if scoreB < 4:
            score = 9
        elif scoreB < 7:
            score = 10
        elif scoreB < 10:
            score = 11
        else:
            score = 12
    elif scoreA == 10:
        if scoreB < 4:
            score = 10
        elif scoreB < 8:
            score = 11
        else:
            score = 12
    elif scoreA == 11:
        if scoreB < 5:
            score = 11
        else:
            score = 12
    else:
        score = 12
    return score



# 儲存每個客戶端的to_window
client_windows = {}
last_timestamps = {}

def print_result(detection_result: vision.PoseLandmarkerResult, output_image: mp.Image,
                 timestamp_ms: int, window_name: str):
    # 在這裡不添加任何變數
    if timestamp_ms < last_timestamps.get(window_name, 0):
        return
    last_timestamps[window_name] = timestamp_ms

    to_window = cv2.cvtColor(
        draw_landmarks_on_image(output_image.numpy_view(), detection_result), cv2.COLOR_RGB2BGR)

    # 更新對應的客戶端窗口
    client_windows[window_name] = to_window

def handle_client(client_socket, addr):
    print(f"Connection from: {addr}")
    data = b""
    payload_size = struct.calcsize("I")  # 消息大小的打包格式
    window_name = f"Client {addr}"  # 為每個客戶端創建唯一的視窗名稱
    client_windows[window_name] = None  # 初始化窗口
    last_timestamps[window_name] = 0  # 初始化時間戳

    # 在這裡為每個客戶端創建新的 MediaPipe 模型
    base_options = python.BaseOptions(model_asset_buffer=open(model_path, "rb").read())
    options = vision.PoseLandmarkerOptions(
        base_options=base_options,
        running_mode=vision.RunningMode.LIVE_STREAM,
        num_poses=num_poses,
        min_pose_detection_confidence=min_pose_detection_confidence,
        min_pose_presence_confidence=min_pose_presence_confidence,
        min_tracking_confidence=min_tracking_confidence,
        output_segmentation_masks=False,
        result_callback=lambda result, img, ts: print_result(result, img, ts, window_name)  # 傳遞 window_name
    )

    with vision.PoseLandmarker.create_from_options(options) as landmarker:
        while True:
            try:
                # 确保接收到的字节数足够提取消息大小
                while len(data) < payload_size:
                    packet = client_socket.recv(4096)
                    if not packet:
                        print(f"Connection closed by {addr}")
                        return
                    data += packet

                packed_msg_size = data[:payload_size]
                data = data[payload_size:]
                msg_size = struct.unpack("I", packed_msg_size)[0]

                # 确保接收到完整的消息（即压缩后的图像数据）
                while len(data) < msg_size:
                    data += client_socket.recv(4096)

                frame_data = data[:msg_size]
                data = data[msg_size:]

                # 反序列化压缩后的 JPEG 数据
                compressed_frame = pickle.loads(frame_data)

                # 使用 OpenCV 解压缩图像数据（JPEG 解码）
                frame = cv2.imdecode(compressed_frame, cv2.IMREAD_COLOR)

                # Convert the frame received from OpenCV to a MediaPipe’s Image object.
                mp_image = mp.Image(
                    image_format=mp.ImageFormat.SRGB,
                    data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                timestamp_ms = int(cv2.getTickCount() / cv2.getTickFrequency() * 1000)

                # 使用 MediaPipe 進行姿勢檢測
                result = landmarker.detect_async(mp_image, timestamp_ms)

                # 显示来自客户端的图像
                if client_windows[window_name] is not None:
                    cv2.imshow(window_name, client_windows[window_name])

                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            except Exception as e:
                print(f"Error handling client {addr}: {e}")
                break

    client_socket.close()

def main():
    # 设置服务器地址和端口
    server_ip = '192.168.50.36'
    server_port = 5555

    # 创建套接字
    server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server_socket.bind((server_ip, server_port))
    server_socket.listen(10)

    print(f"Server is listening on {server_ip}:{server_port}")

    while True:
        # 接受客户端连接
        client_socket, addr = server_socket.accept()

        # 为每个客户端连接创建一个新的线程
        client_thread = threading.Thread(target=handle_client, args=(client_socket, addr))
        client_thread.start()

if __name__ == "__main__":
    main()
